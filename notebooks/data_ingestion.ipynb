# %%
# !pip install --upgrade google-cloud-bigquery pandas-gbq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.9/256.9 kB 4.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-cloud-bigquery
#     Found existing installation: google-cloud-bigquery 3.34.0
#     Uninstalling google-cloud-bigquery-3.34.0:
#       Successfully uninstalled google-cloud-bigquery-3.34.0
# ...

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from google.cloud import bigquery
from google.oauth2 import service_account

# Load the cleaned dataset
cleaned_data_path = '/content/drive/My Drive/bigdata/project/data/cleaned/ipl_merged_cleaned.csv'
df = pd.read_csv(cleaned_data_path)

# Set your GCP project ID and dataset/table
project_id = 'big-data-assignment4-463612'
dataset_id = 'ipl_data'
table_id = 'matches_deliveries_combined'
full_table_id = f"{project_id}.{dataset_id}.{table_id}"

# Upload using pandas-gbq (automatically handles schema)
from pandas_gbq import to_gbq
to_gbq(df, full_table_id, project_id=project_id, if_exists='replace')  # options: 'replace', 'append'

print(f"✅ Data uploaded successfully to BigQuery table: {full_table_id}")
# Out:
# /tmp/ipython-input-5-3346366395.py:7: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(cleaned_data_path)
# 100%|██████████| 1/1 [00:00<00:00, 2146.52it/s]
# ✅ Data uploaded successfully to BigQuery table: big-data-assignment4-463612.ipl_data.matches_deliveries_combined
